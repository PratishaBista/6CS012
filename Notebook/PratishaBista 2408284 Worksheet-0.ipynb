# %% [markdown]
# # <span>Worksheet - 0</span>
# ## <span>Review on Python Programming and Numpy for Deep Learning</span>
# <small>
#
# **Student Name:** Pratisha Bista
# **ID:** 2408284
# **Group:** L6CG1
# **Date:** Feb 23, 2026
#
# </small>

# %%
# python version check
import sys

if sys.version_info.major == 3 and sys.version_info.minor >= 6:
    print("Hello, World!")
    print(f"Python version is {sys.version}")
else:
    print("Please use Python 3.6 or higher.")
# Out:
# Hello, World!
# Python version is 3.13.5 (tags/v3.13.5:6cb20a2, Jun 11 2025, 16:15:46) [MSC v.1943 64 bit (AMD64)]

# %%
# data types
# mutable data types: types whose data is modifiable e.g. list, dict, set, bytearray
# immutable data types: types whose data is non-modifiable e.g. tuple, int, float, bool, str, bytes, frozenset

#list
student_id = [1, 2, 3]
print(f"No. of students currently enrolled: {len(student_id)}")

student_id.append(4)
print(f"Updated no. of students: {len(student_id)}")

shopping_cart = ["Dark chocolate", "Eggs", "Butter"]

shopping_cart.append("Bread")
shopping_cart.remove("Dark chocolate")
print("Items in cart: ", shopping_cart)

#tuple
white = (255, 255, 255)
print("RGB Values of color white: ", white)

location = (27.7172, 85.3240)
print("Kathmandu latitude and longitude: ", location)
# Out:
# No. of students currently enrolled: 3
# Updated no. of students: 4
# Items in cart:  ['Eggs', 'Butter', 'Bread']
# RGB Values of color white:  (255, 255, 255)
# Kathmandu latitude and longitude:  (27.7172, 85.324)

# %%
#common data types
